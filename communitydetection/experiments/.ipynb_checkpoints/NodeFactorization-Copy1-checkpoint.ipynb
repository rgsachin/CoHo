# %%
import numpy as np
from sklearn.decomposition import NMF
from sklearn import preprocessing
import matplotlib.pyplot as plt
min_max_scaler=preprocessing.MinMaxScaler()
import warnings
warnings.filterwarnings('ignore')
import glob
from sklearn.decomposition import FactorAnalysis

# %%
maxNoOfCircle = 30

# %%
nodeLookUp={}
nodeIdx=-1
def getNodeId(rawId):
    global nodeIdx
    if rawId in nodeLookUp:
        nodeId = nodeLookUp[rawId]
    else:
        nodeIdx=1+nodeIdx
        nodeId = nodeIdx
        nodeLookUp[rawId] = nodeId
    return nodeId

# %%
noOfNodes=100
noOfTestSamples=int(0.2*noOfNodes)
testSetExpected=np.zeros((noOfNodes,noOfNodes))
testSetIdxs=np.random.randint(0,noOfNodes-1,noOfTestSamples)

def initForCircle():
    global nodeLookUp
    global nodeIdx
    nodeLookUp={}
    nodeIdx=-1

# %%
def loadCircle(circleFile):
    global noOfTestSamples
    global testSetExpected
    global testSetIdxs
    global nodeLookUp
    global noOfNodes
    circles = open(circleFile, 'r')
    for circle in circles:
        nodesInCircle = circle.split()[1:]
        for node in nodesInCircle:
            getNodeId(node)
    noOfNodes=len(nodeLookUp)
    print 'noOfNodes:',noOfNodes
    noOfTestSamples=int(noOfNodes/5)
    testSetExpected=np.zeros((noOfNodes,noOfNodes))
    testSetIdxs=np.random.randint(0,noOfNodes-1,noOfTestSamples)

# %%
def bigClam(utilMat,noOfCircles):
    global noOfNodes
    global nodeLookUp
    error1={}
    error2={}
    P_C={}
    ssd={}
    testSSE={}
    earlyStop=-1
    for k in range(1,maxNoOfCircle):
        P_C[k]=0
        #print 'to fit util mat with k',utilMat.shape,k
        model = NMF(n_components=k,nls_max_iter=10000,solver='cd',l1_ratio=1,alpha=0.7,init='nndsvd',tol=0.000001)
        F = model.fit_transform(utilMat)
        error1[k]=model.reconstruction_err_
        error2[k]=0
        nodeCircleProbs = np.zeros((noOfNodes,k))
        for i in range(k):
            circleModel = NMF(n_components=1,solver='cd',l1_ratio=0,alpha=1,tol=0.000001,init='nndsvd',nls_max_iter=10000,max_iter=10000)
            F_=F[:,i].reshape(len(F[:,i]),1)
            F_ab_=F_*np.transpose(F_)
            min_max_scaler.fit([0, 100])
            neg_F_ab_=-1*min_max_scaler.transform(F_ab_)*100
            exp_F_ab_=np.exp(neg_F_ab_)
            nodeCircleProbPrime = min_max_scaler.fit_transform(circleModel.fit_transform(exp_F_ab_))
            nodeCircleProb=1-nodeCircleProbPrime
            nodeCircleProbs[:,i]=nodeCircleProb.reshape(len(nodeLookUp))
            P_c=reduce(lambda y,x: np.log(np.maximum(x,0.00000000000000000000000001))+np.log(np.maximum(1-x,0.0000000000000000000001)),nodeCircleProb)
            P_C[k]=P_C[k]+P_c
            error2[k]=error2[k]+circleModel.reconstruction_err_
        reconstructedUtilMat=np.zeros((noOfNodes,noOfNodes))
        testSetActual=np.zeros((noOfNodes,noOfNodes))
        hardNodeInCircle = nodeCircleProbs > 0.5
        hardNodeInCircle = hardNodeInCircle.astype(int)
        for n1 in range(noOfNodes):
            for n2 in range(noOfNodes):
                if (n1 in testSetIdxs) and (n2 in testSetIdxs):
                    testSetActual[n1,n2] = 1 - np.prod(1-np.multiply(hardNodeInCircle[n1],hardNodeInCircle[n2]))
                    #print testSetActual[n1,n2]
        testSSE[k]=np.sum((testSetExpected-testSetActual)**2)
        for n1 in range(noOfNodes):
            for n2 in range(noOfNodes):
                reconstructedUtilMat[n1,n2]=1 - np.prod(1-np.multiply(hardNodeInCircle[n1],hardNodeInCircle[n2]))
        ssd[k]=np.sum(((utilMat/100)-reconstructedUtilMat)**2)
        #print k""",P_C[k],error1[k],error2[k]""",ssd[k],"""np.sum(nodeCircleProbs),"""testSSE[k],np.sum(testSetActual)
        #print k,ssd[k],testSSE[k],np.sum(testSetActual)
        if earlyStop==-1:
            earlyStop = ssd[k]
        elif ssd[k]>earlyStop:
            break
    print np.argmin(ssd),np.argmin(testSSE)
    return np.argmin(ssd),np.argmin(testSSE)

# %%
def loadUtilMatrix(circleFile):
    global nodeLookUp
    print 'circleFile:',circleFile
    utilMat = np.zeros((len(nodeLookUp),len(nodeLookUp)))
    circles = open(circleFile, 'r')
    np.set_printoptions(threshold=1000)
    noOfCircles=0
    for circle in circles:
        noOfCircles=noOfCircles+1
        nodesInCircle = circle.split()
        nodesInCircle = nodesInCircle[1:]
        print len(nodesInCircle)
        for node1 in nodesInCircle:
            for node2 in nodesInCircle:
                node1Idx=getNodeId(node1)
                node2Idx=getNodeId(node2)
                if (node1Idx in testSetIdxs) and (node2Idx in testSetIdxs):
                    testSetExpected[node1Idx,node2Idx]=1
                utilMat[node1Idx,node2Idx]=utilMat[node1Idx,node2Idx]+1
    print 'circles.size',noOfCircles
    return utilMat,noOfCircles

# %%
L_n=5
maxNoOfIterations = 10000
min_del_e=0.0001
trainCircles = 'C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles/*.circles'
featureFile ='C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/features/features_massged.txt'
featureSet=["birthday","education;classes;description","education;classes;from;id","education;classes;from;name","education;classes;id","education;classes;name","education;classes;with;id","education;classes;with;name","education;concentration;id","education;concentration;name","education;degree;id","education;degree;name","education;school;id","education;school;name","education;type","education;with;id","education;with;name","education;year;id","education;year;name","first_name","gender","hometown;id","hometown;name","id","languages;id","languages;name","last_name","locale","location","location;id","location;name","middle_name","name","political","religion","work;description","work;employer;id","work;employer;name","work;end_date","work;from;id","work;from;name","work;location;id","work;location;name","work;position;id","work;position;name","work;projects;description","work;projects;end_date","work;projects;from;id","work;projects;from;name","work;projects;id","work;projects;name","work;projects;start_date","work;projects;with;id","work;projects;with;name","work;start_date","work;with;id","work;with;name"]

# %%
def loadFeatures():
    nodesFeatures = open(featureFile, 'r')
    F_u=[]
    for nodeFeaturesText in nodesFeatures:
        nodeFeatures = nodeFeaturesText.split(' ')
        node = nodeFeatures[0]
        featureValue={}
        for featureValueText in nodeFeatures[1:]:
            featureValuePair=featureValueText.split(':')
            print featureValuePair
            featureValue[featureValuePair[0]]=featureValuePair[1]
        f_u=[]
        for idx in range(len(featureSet)):
            f_u_i=-1
            if(featureSet[idx] in featureValue):
                print featureValue[featureSet[idx]]
                f_u_i = int(featureValue[featureSet[idx]].strip())
            f_u.append(f_u_i)
        F_u.append(f_u)
    print F_u
            
loadFeatures()
# Out:
# ['last_name;0']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-62c0057073ed> in <module>()
#      20     print F_u
#      21
# ---> 22 loadFeatures()
#      23
#
# <ipython-input-33-62c0057073ed> in loadFeatures()
#       9             featureValuePair=featureValueText.split(':')
#      10             print featureValuePair
# ---> 11             featureValue[featureValuePair[0]]=featureValuePair[1]
#      12         f_u=[]
#      13         for idx in range(len(featureSet)):
#
# IndexError: list index out of range

# %%
def trainCommunityMembership(utilMat,noOfCircle):
    circleModel = NMF(n_components=noOfCircle,solver='cd',l1_ratio=0,alpha=1,tol=0.000001,init='nndsvd',nls_max_iter=10000,max_iter=10000)
    circleModel.fit(utilMat))
    return circleModel

# %%
def predictNodeCommunityMembership(utilMat,circleModel):
    return circleModel.transform(utilMat)

# %%
def fitAndRegenerateUtilMatrix(utilMat,noOfCircle):
    circleModel = trainCommunityMembership(utilMat,noOfCircle)
    F_u_c = predictNodeCommunityMembership(utilMat,circleModel)
    return F_u_c

# %%
def buildUtilMatFromCircleMembership(F_u_c):
    return np.dot(nodeCircleMembership,np.transpose(nodeCircleMembership))

# %%
def computeFittingError(F_uv_l,F_uv_c):
    return np.sum(((F_uv_l-F_uv_c)**2)

# %%
def initUtilMatrix(N,k):
    return np.ones((N,N))*.25*k

# %%
def trainLatentAspect(X_uv,F_uv):
    fa = FactorAnalysis(n_components=k)
    fa.fit(X,F_uv)
    return fa

# %%
def predictNodeCommunityMembership(latentModel,X,k):
    N = X.shape[0]
    L=np.zeros((N,N,L_n))
    for u in range(N):
        for v in range(N):
            L[u,v]=latentModel.transform(generateNodePairFeatures(u,v))
    F_uv_l=initUtilMatrix(N,k)
    e_prev=0
    F_u_c = np.zeros(N,k)
    for itr in range(maxIteration):
        for u in range(N):
            for v in range(N):
                F_uv_l[u,v]=nodePairCirclesModel.fit_transform(L[u,v])
        F_u_c = fitAndRegenerateUtilMatrix(F_uv_l,k)
        F_uv_c = buildUtilMatFromCircleMembership(F_u_c)
        F_uv_c[F_uv_c<0]=0
        e = computeFittingError(F_uv_l,F_uv_c)
        if (np.absolute(e-e_prev)/e_prev<=min_del_e):
            break;
    return F_u_c,e

# %%
for circleFile in glob.glob(trainCircles):
    trainLatentAspect()
    loadCircle(circleFile)
    utilMat,noOfCircles = loadUtilMatrix(circleFile)
    k_ssd,k_testSSE=bigClam(utilMat,noOfCircles)
    print 'circle - actual,predicted',noOfCircles,k_ssd,k_testSSE
# Out:
# noOfNodes: 387
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\10395.circles
# 93
# 7
# 10
# 128
# 187
# 8
# 5
# circles.size 7
# 0 0
# circle - actual,predicted 7 0 0
# noOfNodes: 78
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\10929.circles
# 11
# 8
# 13
# 12
# 11
# 24
# circles.size 6
# 0 0
# circle - actual,predicted 6 0 0
# noOfNodes: 295
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\11014.circles
# 35
# 71
# 53
# 17
# 10
# 9
# 19
# 28
# 57
# 5
# circles.size 10
# 0 0
# circle - actual,predicted 10 0 0
# noOfNodes: 106
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\11186.circles
# 7
# 5
# 5
# 33
# 8
# 5
# 6
# 70
# 15
# 6
# 19
# 9
# circles.size 12
# 0 0
# circle - actual,predicted 12 0 0
# noOfNodes: 31
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\11364.circles
# 6
# 6
# 17
# 9
# circles.size 4
# 0 0
# circle - actual,predicted 4 0 0
# noOfNodes: 386
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\11410.circles
# 33
# 139
# 81
# 101
# 7
# 8
# 6
# 12
# 6
# circles.size 9
# 0 0
# circle - actual,predicted 9 0 0
# noOfNodes: 535
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\12800.circles
# 35
# 5
# 10
# 167
# 68
# 41
# 17
# 181
# 243
# 9
# 75
# 34
# 9
# 14
# circles.size 14
# 0 0
# circle - actual,predicted 14 0 0
# noOfNodes: 51
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\13353.circles
# 5
# 14
# 7
# 19
# 17
# 16
# circles.size 6
# 0 0
# circle - actual,predicted 6 0 0
# noOfNodes: 128
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\1357.circles
# 10
# 10
# 7
# 8
# 9
# 16
# 31
# 64
# 10
# 39
# circles.size 10
# 0 0
# circle - actual,predicted 10 0 0
# noOfNodes: 323
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\13789.circles
# 5
# 8
# 16
# 31
# 10
# 10
# 31
# 101
# 47
# 16
# 18
# 83
# circles.size 12
# 0 0
# circle - actual,predicted 12 0 0
# noOfNodes: 514
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\15672.circles
# 9
# 41
# 44
# 31
# 73
# 66
# 6
# 23
# 17
# 9
# 6
# 5
# 20
# 6
# 32
# 11
# 19
# 89
# 125
# 233
# 31
# 20
# 15
# 10
# 19
# circles.size 25
# 0 0
# circle - actual,predicted 25 0 0
# noOfNodes: 165
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\16203.circles
# 60
# 57
# 16
# 35
# circles.size 4
# 0 0
# circle - actual,predicted 4 0 0
# noOfNodes: 101
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\16378.circles
# 28
# 5
# 5
# 5
# 59
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 206
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\16642.circles
# 15
# 15
# 11
# 33
# 33
# 12
# 6
# 55
# 5
# 15
# 12
# 12
# 82
# 48
# 39
# 6
# 33
# circles.size 17
# 0 0
# circle - actual,predicted 17 0 0
# noOfNodes: 103
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\16869.circles
# 12
# 19
# 38
# 26
# 14
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 41
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\17951.circles
# 8
# 13
# 20
# 12
# 8
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 43
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\18005.circles
# 16
# 24
# 5
# circles.size 3
# 0 0
# circle - actual,predicted 3 0 0
# noOfNodes: 118
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\1839.circles
# 54
# 32
# 35
# 34
# 23
# 11
# 5
# 6
# circles.size 8
# 0 0
# circle - actual,predicted 8 0 0
# noOfNodes: 43
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\18543.circles
# 9
# 5
# 16
# 5
# 8
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 134
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\19129.circles
# 74
# 14
# 22
# 18
# 39
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 271
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\1968.circles
# 28
# 6
# 85
# 60
# 6
# 11
# 12
# 6
# 10
# 9
# 7
# 76
# 47
# 26
# circles.size 14
# 0 0
# circle - actual,predicted 14 0 0
# noOfNodes: 245
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\19788.circles
# 9
# 26
# 24
# 7
# 8
# 53
# 7
# 12
# 11
# 5
# 6
# 15
# 16
# 51
# 28
# 50
# circles.size 16
# 0 0
# circle - actual,predicted 16 0 0
# noOfNodes: 99
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\2255.circles
# 51
# 6
# 93
# circles.size 3
# 0 0
# circle - actual,predicted 3 0 0
# noOfNodes: 164
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\22650.circles
# 6
# 6
# 10
# 12
# 19
# 16
# 14
# 7
# 6
# 65
# 7
# 9
# circles.size 12
# 0 0
# circle - actual,predicted 12 0 0
# noOfNodes: 108
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\22824.circles
# 6
# 10
# 33
# 9
# 14
# 12
# 8
# 9
# 8
# 9
# 10
# circles.size 11
# 0 0
# circle - actual,predicted 11 0 0
# noOfNodes: 141
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\23157.circles
# 6
# 28
# 27
# 12
# 35
# 22
# 76
# 34
# 14
# 26
# 13
# 13
# 17
# 22
# 11
# circles.size 15
# 0 0
# circle - actual,predicted 15 0 0
# noOfNodes: 491
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\23299.circles
# 88
# 9
# 16
# 48
# 27
# 38
# 38
# 18
# 6
# 83
# 40
# 8
# 28
# 12
# 76
# circles.size 15
# 0 0
# circle - actual,predicted 15 0 0
# noOfNodes: 101
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\2365.circles
# 7
# 7
# 23
# 5
# 18
# 36
# 10
# 24
# 8
# 14
# circles.size 10
# 0 0
# circle - actual,predicted 10 0 0
# noOfNodes: 102
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\239.circles
# 27
# 46
# 13
# 19
# circles.size 4
# 0 0
# circle - actual,predicted 4 0 0
# noOfNodes: 39
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\24758.circles
# 9
# 13
# 6
# 8
# 8
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 278
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\24857.circles
# 11
# 14
# 72
# 92
# 17
# 36
# 10
# 26
# circles.size 8
# 0 0
# circle - actual,predicted 8 0 0
# noOfNodes: 122
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\25159.circles
# 69
# 9
# 55
# 8
# 17
# 5
# 26
# 8
# 10
# 10
# 5
# 13
# 14
# 12
# circles.size 14
# 0 0
# circle - actual,predicted 14 0 0
# noOfNodes: 124
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\25568.circles
# 17
# 22
# 53
# 30
# 6
# 5
# 10
# 5
# 38
# 21
# 17
# 10
# circles.size 12
# 0 0
# circle - actual,predicted 12 0 0
# noOfNodes: 203
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\25773.circles
# 5
# 35
# 6
# 19
# 17
# 37
# 9
# 94
# 5
# 9
# 58
# circles.size 11
# 0 0
# circle - actual,predicted 11 0 0
# noOfNodes: 69
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\26321.circles
# 7
# 16
# 27
# 11
# 5
# 7
# circles.size 6
# 0 0
# circle - actual,predicted 6 0 0
# noOfNodes: 321
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\26492.circles
# 6
# 9
# 13
# 143
# 41
# 22
# 10
# 6
# 6
# 11
# 6
# 6
# 13
# 34
# 17
# 18
# circles.size 16
# 0 0
# circle - actual,predicted 16 0 0
# noOfNodes: 177
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\27022.circles
# 126
# 36
# 144
# 5
# 28
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 25
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\2738.circles
# 6
# 5
# 7
# 7
# circles.size 4
# 0 0
# circle - actual,predicted 4 0 0
# noOfNodes: 65
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\2790.circles
# 6
# 9
# 11
# 5
# 16
# 54
# 11
# 5
# circles.size 8
# 0 0
# circle - actual,predicted 8 0 0
# noOfNodes: 68
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\2895.circles
# 27
# 30
# 18
# 6
# 14
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 159
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\3059.circles
# 44
# 10
# 16
# 18
# 9
# 11
# 14
# 84
# 64
# 7
# 8
# 5
# 7
# 36
# 11
# circles.size 15
# 0 0
# circle - actual,predicted 15 0 0
# noOfNodes: 251
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\345.circles
# 7
# 48
# 145
# 30
# 27
# 16
# 6
# circles.size 7
# 0 0
# circle - actual,predicted 7 0 0
# noOfNodes: 665
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\3735.circles
# 8
# 132
# 5
# 18
# 75
# 9
# 26
# 335
# 132
# 21
# 71
# 48
# 64
# 19
# 91
# 25
# 16
# 70
# 8
# 12
# 24
# circles.size 21
# 0 0
# circle - actual,predicted 21 0 0
# noOfNodes: 422
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\4406.circles
# 8
# 8
# 23
# 304
# 48
# 35
# 41
# 14
# 7
# 75
# 64
# 13
# 5
# 18
# 17
# 16
# 9
# 7
# 5
# 26
# 14
# 22
# 11
# 7
# 20
# 10
# 20
# 230
# circles.size 28
# 0 0
# circle - actual,predicted 28 0 0
# noOfNodes: 252
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\4829.circles
# 26
# 138
# 6
# 66
# 30
# 18
# 6
# 37
# 15
# 6
# 13
# circles.size 11
# 0 0
# circle - actual,predicted 11 0 0
# noOfNodes: 310
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\5212.circles
# 5
# 33
# 13
# 20
# 9
# 10
# 131
# 9
# 6
# 12
# 22
# 96
# 60
# 104
# 23
# 7
# 14
# 20
# 18
# circles.size 19
# 0 0
# circle - actual,predicted 19 0 0
# noOfNodes: 235
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\5494.circles
# 50
# 22
# 5
# 8
# 6
# 81
# 41
# 17
# 19
# 119
# 6
# circles.size 11
# 0 0
# circle - actual,predicted 11 0 0
# noOfNodes: 169
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\5881.circles
# 9
# 21
# 6
# 75
# 15
# 49
# circles.size 6
# 0 0
# circle - actual,predicted 6 0 0
# noOfNodes: 237
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\611.circles
# 42
# 108
# 16
# 8
# 22
# 51
# 40
# 13
# 9
# 18
# circles.size 10
# 0 0
# circle - actual,predicted 10 0 0
# noOfNodes: 113
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\6413.circles
# 59
# 36
# 30
# circles.size 3
# 0 0
# circle - actual,predicted 3 0 0
# noOfNodes: 198
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\6726.circles
# 56
# 5
# 24
# 114
# circles.size 4
# 0 0
# circle - actual,predicted 4 0 0
# noOfNodes: 217
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\7667.circles
# 15
# 22
# 122
# 59
# 16
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 121
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\8100.circles
# 6
# 6
# 5
# 43
# 22
# 33
# 6
# 21
# 18
# circles.size 9
# 0 0
# circle - actual,predicted 9 0 0
# noOfNodes: 80
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\8239.circles
# 16
# 6
# 42
# 8
# 11
# circles.size 5
# 0 0
# circle - actual,predicted 5 0 0
# noOfNodes: 218
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\8553.circles
# 14
# 9
# 10
# 25
# 14
# 15
# 8
# 12
# 79
# 38
# circles.size 10
# 0 0
# circle - actual,predicted 10 0 0
# noOfNodes: 111
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\8777.circles
# 6
# 5
# 21
# 60
# 82
# 7
# 98
# 13
# 16
# 11
# 13
# circles.size 11
# 0 0
# circle - actual,predicted 11 0 0
# noOfNodes: 90
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\9103.circles
# 5
# 9
# 9
# 5
# 12
# 9
# 54
# 9
# circles.size 8
# 0 0
# circle - actual,predicted 8 0 0
# noOfNodes: 191
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\9642.circles
# 28
# 6
# 12
# 8
# 10
# 66
# 34
# 7
# 20
# 6
# 57
# 13
# 13
# 14
# 8
# 33
# 49
# 26
# 7
# 8
# 23
# circles.size 21
# 0 0
# circle - actual,predicted 21 0 0
# noOfNodes: 92
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\9846.circles
# 6
# 8
# 5
# 6
# 45
# 65
# 11
# 5
# 29
# circles.size 9
# 0 0
# circle - actual,predicted 9 0 0
# noOfNodes: 439
# circleFile: C:/Users/sachin/Documents/sanctorium/research/communitydetection/data/circles\9947.circles
# 9
# 158
# 31
# 8
# 13
# 8
# 49
# 5
# 137
# 11
# 59
# 21
# 17
# circles.size 13
# 0 0
# circle - actual,predicted 13 0 0

# %%
# %matplotlib inline

def plotHist(dictValues):
    plt.bar(range(len(dictValues)), dictValues.values())
    plt.xticks(range(len(dictValues)), dictValues.keys())
    plt.show()

#plotHist(P_C)
plotHist(ssd)
plotHist(testSSE)
